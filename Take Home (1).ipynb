# %% [markdown]
# <div class="alert alert-block alert-light"><h2 style="font-size:36px"style="padding:1px"><center>Take Home - Notebook Developer Submission </center></h2><center> All answers contain the reasoning behind the choices and route/reasoning taken. </div>

# %% [markdown]
# <div class="alert alert-block alert-info"><h2 style="font-size:16px"style="padding:1px"><center>Q1. READING BEST-PRACTICE PUBLICATIONS </center></h2>
# <p>When developing a new pipeline, or improve an existing one, a good starting point is a review paper that discusses the best practices. If you need to develop a pipeline, or improve an existing one, identify a single publication that would like to follow. You don’t have to read the full paper! Just search for the relevant papers, take a brief look, and select the one you would want to follow in detail. Share the link to the publication. During your search, you may have also found other good papers. Why did you pick the first one? Which papers were number 2 or 3? For this exercise, you may pick either RNA-Seq or ChIP-Seq or single nucleotide variant calling.
# Using Python, Pandas, Numpy and other common dependencies. All answers contain the reasoning behind the choices and route taken. </div>
#
# <div class="alert alert-block alert-warning"><h2 style="font-size:16px"style="padding:1px"><center>Q1. ANSWER: </center></h2>
# <h4>RNA-SEQ</h4>
# <h6>1</h6> A survey of best practices for RNA-seq data analysis. Conesa A, Madrigal P, Tarazona S, Gomez-Cabrero D, Cervera A, McPherson A, Szcześniak MW, Gaffney DJ, Elo LL, Zhang X, Mortazavi A. Genome Biol. 2016 Jan 26;17:13. doi: 10.1186/s13059-016-0881-8. Erratum in: Genome Biol. 2016;17(1):181. PMID: 26813401; PMCID: PMC4728800.
# Direct Link: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4728800/
#
# The paper breaks the process (RNA-Seq) in modules. These modules are then studied for it's characteristics for the signs that point either to a good pipeline or the reasons along the way for the need to improvement of a ‘faulty’ pipeline.
#
# <h6>2</h6>
# Improving the Flexibility of RNA-Seq Data Analysis Pipelines.Phan JH, Wu PY, Wang MD.  IEEE Int Workshop Genomic Signal Process Stat. 2012 Dec;2012:70-73. doi: 10.1109/GENSIPS.2012.6507729. PMID: 27536420; PMCID: PMC4985025.
# Direct Link: https://www.ncbi.nlm.nih.gov/pmc/articles/PMC4985025/
#
# <h6>3</h6>
# Computational Testing for Automated Preprocessing 2: Practical Demonstration of a System for Scientific Data-Processing Workflow Management for High-Volume EEG. Cowley BU, Korpela J. Front Neurosci. 2018 Apr 10;12:236. doi: 10.3389/fnins.2018.00236. PMID: 29692705; PMCID: PMC5902528.
# Direct Link:https://www.ncbi.nlm.nih.gov/pmc/articles/PMC5902528/

# %% [markdown]
# <div class="alert alert-block alert-info"><h2 style="font-size:16px"style="padding:1px"><center>Q2. EVALUATING TOOLS </center></h2>
# <p> A common step in many pipelines is pre-processing reads before alignment, to remove low quality bases and trim adapters. There are multiple tools available for this purpose, e.g., TrimGalore, fastp and Atropos.
# I.	Which among the 3 would you use? (or would you use a different tool?)
# II.	What are the pros and cons of each?</div>
#
# <div class="alert alert-block alert-warning"><h2 style="font-size:16px"style="padding:1px"><center>Q2. ANSWER </center></h2>
# <p> I - FASTP
# <p> <br>
# <h4>II</h4>
#
# <h4>TrimGalore</h4> <br>
# Cons:<br>
# Requires separate installation of Cutadapt and FastQC.
# Adapter auto-detection even if no adaptor sequence is supplied.Yet the adaptor auto-detection can be overwritten and manually supplied.
# <p>
# Pros: <br>
# One process in two-steps, it's able to do this by wrapping around two separate tools (Cutadapt and FastQC) joining them in one single process inside TrimGalore which takes output from the first to the second without a need for extra coding steps.
# <p>
# <h4>FASTP<br></h4>
# Multi-threading<br>
# 2 to 5 faster times than FASTQ<br>
# It includes most features of FASTQC + Cutadapt + Trimmomatic + AfterQC while running 2–5 times faster than any of them alone.<br>
# <p>
# <h4>Atropos<br></h4>
# Artificially methylated bases at the 3′ ends of reads.<br>
# paired-end read trimming accuracy that is superior to other state-of-the-art tools, and it is among the fastest read trimming tools when a moderate number of parallel execution threads are used. <br>
# Achieves a performance increase that is roughly linear with the number of threads used, making it the fastest tool when eight or more threads are available.<br>

# %% [markdown]
# <div class="alert alert-block alert-info"><h2 style="font-size:16px"style="padding:1px"><center>Q3. VALIDATING PIPELINES </center></h2>
# <p>When new users analyze their data on Basepair, a question they have is: “can I trust these results?” How will you validate a pipeline to show the accuracy? You don’t have to validate the pipeline, just provide an outline of how you will go about it. For this exercise, you may pick either RNA-Seq or ChIP-Seq or single nucleotide variant calling.
# </div>
#
# <div class="alert alert-block alert-warning"><h2 style="font-size:16px"style="padding:0px"> ANSWER </h2>
# Quality checks start with the pre-processing aspects of the analysis. Certain criteria have to be met for a significant result.
# Experiment validation and experiment quality checks: Trimming, poly A, GC ratio, percentage of read alignment. Once these are within known standards the sample is accepted as ‘validated’ and not the probable source of any issues.
#
# Depending on the desired analysis certain information, data, metadata and tools need to be available. For example:
# <p>  ● Enrichment Analysis: Background databases need to be available and the User analyzed data needs to follow the same standards.
# <p>  ● Principal Components Analysis:The number of components areas in which over a total of 80% of features will fall need to be at most four components for most visualization techniques. If a 3D view is available up to 6 components can be acessed.
# Usually a 2D view with up to four components is used. If those four main components do not account for over 80% of the components either reduced total % found on main components areas, expanding to 3D and obtaining another 2 dimensions of components, further data cleaning or the total % found into the main components can be used as a clear indication of issues that need to be resolved in the analysis.
# </div>
#
# <div class="alert alert-block alert-warning"><h2 style="font-size:16px"style="padding:1px">Program/Script Pipeline Validation and Quality Checks:</h2>
# <p>
#
# <p> <h3> 1. UNIT TESTING (DATA SIDE VALIDATION)</h3> <p>
# Unit testing allows the pipeline to be broken down into modules and have each of its modules tested for the acceptable input, values and necessary outputs. <p>Some of these include testing: Data type, Data size,Data structure and values.
# <p> Singleton Issue Alerts: These are Scripts that exist parallel to the main pipeline and called by the pipeline to perform a check, if validated continue pipeline. If not-valid or pre-defined singleton issue definitions are not met: <p>
#         <h5>STOP ALERT  </h5><p>
#             Contains: <p> ISSUE-NAME and ISSUE-TYPE-SPECIFIC-ID; <p> Possible reasons why ISSUE-NAME usually occurs; <p> Possible conducts to be taken.<p>
#             Is documented:<p>
#             Keeps issue-name, issue-specific-ID, date and time, <p>
#             and Sample(s) ID:
#                 <p> * Assigned automatically per sample in run. Each pipeline run is one analysis and the samples contained in that batch are also numbered and identified.
#                 <p> * A pipeline can be used with 1 to unlimited number of samples (unless maximum samples per batch have been limited by  basepair.)
#                  <p>   * Assigned as run-ID-sample-ID which can be used to see all the run ID pre-sets, type of analysis and other information, the sample-ID can be used to gather all sample specific information. <p>
#
# <p> <h5> REASONING FOR STOP ALERT:  </h5><p> Detailing why the basepair platform stops when this issue occurs. <p>
# Provides link to literature on issue. Provides link to possible solutions.<p>
#  * Some of these solutions can be made available with a new button that appears in the reasoning if a script able to correct the issue is available.
# <p>
# <h6> OR IGNORE ALERT and CONTINUE ANALYSIS BUTTON. </h6>
# Which gives the user overwrite control. <p>
# <p>  <p>
# Most of these are performed by tools but experiment-user specific code checks might be added to an automated analysis. Singleton issue validation of: Percentage of ____ GC content. Presence of Adaptor. Fragment Size. ETC
# <p>  <p>
#     <h3>     2. GOLD STANDARD </h3>
#                 Literature available data that is recognized as a gold standard for assay type that have known results for
#                 known pipelines. The gold standard data will run throught the new proposed pipeline which needs to provide
#                 similar or better  results than those pipelines tested in the literature.
# <p>
# <p>
#     <h3>      3. VISUALIZATION </h3>
#                 Graphs and Figures can be used to look for issues in the data/analysis/ predetermined variables and/or on the
#                 programing scripts.
# <p>
# <p>
#      <h3>     4. UNIT TEST (PROGRAMING SIDE VALIDATION) </h3>
#                 Break the pipeline into single task modules and test each of them.
#                 For example:Import data module, Clean data-standardize module, Create Matrix module,Calculate distance module, VisualizationT1 module, VisualizationT2 module. </div>
# <div class="alert alert-block alert-warning"><h2 style="font-size:10px"style="padding:0px"></h2>
# When re-assembling the pipeline the end of each module can contain de-tour. Meaning the module output has correct data, type and is working as validated. The de-tour is the parallel checks and analysis specific-special tests and/or commands. For example a de-tour can higher restrictive criteria before using that module output to start a new sideways route and that same output will also be used to continue the main pipeline.
#
# In this one Only one main pipeline exists and from that always same input location/script/computation the other possibilities branch out. This saves in computation the data is cleaned, wrangled, organized and standardized just one time for any subsequential analysis.
#
# Once the sample data in uploaded the platform does not need to ever perform this step for the same sample unless the user deletes the analysis read data file.
# </div>
#
# <div class="alert alert-block alert-warning"><h2 style="font-size:16px"style="padding:1px">User Stories</h2>
# <p>
#
# USER STORIES<br>
# Another important part of developing and validating a pipeline is the use of user stories. Inside academia user stories are almost never given too much thought, this is true especially for higher level and appliance science.
#
# A user story has some general basic components:
#
# User knowledge:
# A PhD in the field will need a different view of the information when compared to
# for example a governmental user that has been tasked with evaluating if the invested governmental resources
# were able to generate a real outcome. In this example case the PhD can browse quickly over the menus, settings and options.
# While a government official might turn desperate without a general roadmap of the project with simple explanations and clear division of data, research progress and its future.
#
# User wants:
# What do the users want from the tools/website/platform.
# How did they end up at that location asking a question?
#
# User issues:
# What are the issues encountered; For instance, couldn't understand settings for (_____), can a specific request for a change to code be submitted, among so many others.
#
# A Necessary Epic
# An epic is necessary for the development team. What we call an epic can be defined as a large collection of users stories.
# This epic can be seen as multiple facets of the same 'point' by respecting the view, perception and even distortion
# that is a part of any story a development team can deliver a truly outstanding product.
# That will be able to supply the required information from a fifth grade assignment, to a news piece and going all the way up to the highest level of science which needs discovery, ideas, possibilities that needs to take assumptions and comparable insights to see and write, to document and develop what does not exist yet.
# This maybe a new branch of science, a revolutionary drug or a simple point change to something common that creates a new view, a new informed understanding, based and motivated by scientific guidelines and thus stepping into the future.
#
# While it may sound glamorous and high-profile even, user stories are generally just a few simple phrases long. It’s up to the development and research team to use each of those stories to branch out, create resulting a final built capable of information a large range of knowledge, capable of providing real & significant biological/scientific meaning, clearly justify assumptions and readily present the background and bases for all steps, actions and decisions that from the first click all the way to final results.
#
# Just as a matter of curiosity, the following are some examples of user stories:  <br>
# - As a user, I would like to be able to quickly write down my thoughts so that I can return to this specific location/information and analysis step. <br>
# - As a user, I would like to be able to compare across final results in clean and easy to see visualization. To view and compare multiple tries, backgrounds and be able to slowly build a large 'dashboard' around my work. <br>
# - As a user, I would like to have a general tool that counts my most common issues/problems/alerts in a report, showing sample data and metadata. A problem/issue report that would look what is common among those. <br>
# - As a user, I would like to have an analysis pipeline diagram automatically generated. That can be specific to my data, work, question and other needs. ** This tell the development team to create a hierarchical tree of the analysis pipeline, create an overview of the user data and its metadata categories. The initial diagram will be complete, with each pipeline step, the changes between one step and the next. The other possible routes that the user-specific data and analysis at the specific-point can take, among others. The hierarchical view will allowed the user to select/unselect steps, metadata, pipeline branching which can be taken-out or reduced. Among many other possible features. <br>
# <br>One interesting feature I would add: Show point were this analysis vary its values, definitions, limits, etc and create a table displaying that step possible variations informing significant, noise, reasoning while keeping in the analysis documentation a registered pipeline decision that was based on science, literature, known analysis tools/limits, this table can dispel any reasons to doubt the researcher choices and validates the result.
# <p>
# - As a user, I would like to study the analysis branches and its recommendations to design all my project as cleanly as possible, starting at sample and assay protocols. Which are also when available part of the platform information.
# - As a user I would like to have a real information-science heavy result and final report.
# <p>* This can and will be available by choosing next to the steps and metadata to add or not literature and background information. The selected fields and data will use known governmental repositories and databases to create the Almighty-report. Default settings will search for the last 10 years, group, clean, standardize and use Natural Language Processing to created correlations.
# <p>
# Which means all the data and its result has proven, tested, validated, corroborated and multi-feature-variable testing available. With The background grouped by its assay, tissue, cell line, disease, drug or other user defined words or three-word phrase. These will also be available in network view for each category and as a full network. From this network a highlight red ! marks the places in that due to network, its nodes, distances and processes have been found to have higher significance (as a theory and a new possibility.)
# <p>
# *** This can be easily seen due to modules, their Lego-assembly capabilities, constrains, backgrounds, limits, natural language processing and so on as the beginning, the structure ready-like beginning of machine learning taking the governmental repositories, literature and possibilities to find, adapt, suggest and create (since it will be able to study the successful creative science processes.)
# <p>
# - As a user, I would like to be able to collaborate with other users that have similar data, or write down what is the data, assay, type, cells, disease, etc.<br> I am open to collaborate. * Any data, diagram-schema, user-specific-code-changes that are part of a user who wishes to collaborate work will be round-searched once every 15 days, all matches returned and an automatic email sent from those open to collaborate to others who are also collaboration-open.<p>
# <p>
# If a User goes to the collaboration page select the project, add relevant information, any restrictions (for instance country due to source of funding), among others will connect those willing to collaborate with no maximum collaborators/institutions numbers. If any sample is  found to be repeated (all data and metadata is cross-referenced) the repeated sample will be evaluated and a final value found by the best protocols and validation methods found, this will assign the general sample collaboration characteristics and give the specific sample result a slightly higher significance value since it’s been tested in different locations, labs, reagents and researchers. This sample needs to be given a higher weight when compared to a single sample with that was only tested once due to for example not-enough sample recovered. This second case cannot be taken with equal weights to thoroughly validated, triplicate tested in multi-locations.<p>
# <p>
# * All this information of weights, reasoning and the step-by-step calculations can be easily viewed, sorted, used to define sample-types that being too low-weighted and badly represented in the full sample-set to create an open call to supplement these issues. A sample of weaker weight might be the most important, informative, significant find but that can only be tested if a way to add significance to that specific-sample is found. Some bioinformatics tools can be of help with this.
# And many more.
# <p>
# <p>
# Continued after the last question answer.

# %% [markdown]
# <div class="alert alert-block alert-info"><h2 style="font-size:16px"style="padding:1px"><center>Q4. PROGRAMMING </center></h2>
# In a building, people have either cats or dogs. The animals are either white or black.
# 1.	Given a list of animals and another list of colors, where the animal and colors are in matched order, count the number of animal of a given color.
# ●	Preferably complete this assignment in Python and send the source code.
# </div>
#
# <div class="alert alert-block alert-warning"><h2 style="font-size:20px"style="padding:1px"><center>Q4. ANSWER </center></h2>
# <p>
# Lists are a type of (linear) data type in which order is established and can only be changed by resetting the list. That being true the order in which a list is presented can matter for the subsequent analysis. The way to count the animals also depends on the desired outcomes and it's uses.
# I would define both sets of information (animal & color) as two lists. Since lists have a defined order this would make it easy to  assign animal  to color. The first value of lsta would be assigned to the first value of lstb and so on. This is achieved easily by staking the two list and thus creating a dataframe.
# <br><br>
# Since the data/information  is taken as a:<br>
# 1x Number_of_animals <br>
# 1x Number_of_colors.<br>
# This those lists can be stacked creating a 2 x Number_of_animals dataframe with unique index fr future analysis steps.<br>
# <p><p>
# -- As a validation step, a simple but necessary unit test can be performed that will validade and increase the significance and trustworthiness of the result. All programing steps should be validated via unit tests and this is a perfect point for it.
# <p>
#           This unit test will test the programing, the data, metadata collected and informed) both lists can be have it's number of values contained in the set-list compared.  This test is easy to perform by supplying the programming script with the two lists that will have it's N x M dimensions compared, and those N x M dimensions should be equal.<br>
# <p>
#         If the number of animals in lsta is equal the number of colors in lstb than the analysis can continue otherwise an error message should be display saying the number of values of both lists supplied are different and therefore some data\ manipulation/wrangling is necessary. <br>
# <p>
#     It is suggested that for missing colors a new color category is created as NA and for all animals that do not contain the color information the NA category is added as color. This new category will also return the total number of animals without the colorvalue assigned. <br>
# <p><p>
#     The NA category is only informative and cannot be taken as a single color thus it should not be displayed in the main analysis result when comparing colors and animals and should be displayed separately since it cannot be displayed as a direct relationship to single animal-single color rather is the unknown animal and/or color and should be highlighted in a report table showing all NA with the information available and the position it occupied in the original list.Informing the users that the information in this particular table was not  included in the analysis.  The metadata is the information, description and all other known characteristics of the measured data that can be used to enrich the data.<br>
# For example knowing that black cats in the specific region are mostly males and weight over 5kg can make this result more significant. This might be due to the genetics of the black cats in that region have higher survival rates for males, thus more males reach adulthood. Which is important for any further studies delimitation, this would raise questions such as: Is there any Y related advantages that are better suited for the location, if there are mutation on a Y gene that causes the carriers to grow bigger and heavier.
# <p>
# When compared to the same species (if available) somewhere does this difference becomes significant.<br>
# It can also be used for enrichment analysis, for example when comparing color, weight, and etc between the population being studied and other similar populations can be ‘inferred’ as a possible step.
# <p><p>
# If the most significant characteristics found when analysing the data and metadata, usually the ones that fall into the 3 to 4 main components (in a main components analysis) is compared to other known black cats around the globe by region the characteristics of other populations that are similar to the population under study can be taken in as assumption for further study. For example: If an island in Japan have similar occurrence of male black cats with slight deviation up on their weight, what else is known about the Japanese island population that can be taken as possible to the current study. Thus suggesting the next direction of the research with clear data, enrichment analysis, higher significance and real biological meaning. All easily seem by principal components analysis, tables, pizza charts and direct comparisons and their calculated significance.
# <p>
# All of this guides, motivates and justifies the research, next steps, deals with noise in the data by establishing a threshold of similar data and measurements that is validated on the literature.
# <p>
# All of this steps, data, collection steps and data wrangling can and does justify the project and the need for further tests and analysis. It also suggests reasons for concern, possible nutrient depletion and even possible medications to be used for example black cats losing too much fur since the known health loss is known and the genes for the cat fur coat are known, a differential gene expression analysis of those genes might show for instance a fur geneset for a much colder region and thus raise the hypothesis of temperature regulation of fur shedding.
#  <p>
# If found to be true a fur thinning medication might be suggested as a solution, finner fur resulting in lower body temperature and less shedding. In this case, the data is the specific-animal and the metadata available the color.
#  <p>
# Other examples of metadata include for example animal weight, age, species, single or multicolor, male or female, carnivore/herbivore or omnivore, among other caracteristics.
# <p>
# It's important to inform the user that metadata is important and without it a result has little to no significant biological meaning. Thinking of subsequential analysis is always good to find ways to facilitate the handling of data, this way I would use the two lists created from probably two text files and use them to create a pandas dataframe.
#
# </div>

# %%
import os
import csv
import sys

from pandas import *
import pandas as pd
import numpy as np
from collections import Counter

# %%
with open("Animals1.txt") as f1, open("Colors1.txt") as f2:
        line_file1 = f1.readline()
        line_file2 = f2.readline()
        #print(line_file1, line_file2)
        
        Animalwords = line_file1.split() 
        Colorswords = line_file2.split() 
        print(Animalwords) 
        print(Colorswords)
        print("\nNumber of Animals = ", len((Animalwords)))
        print("Number of Colors = ", len((Colorswords)))
        
        if len(Animalwords) != len(Colorswords):
                print("Different size lists. PIPELINE STOP ALERT.\n")
                print("Txt files contain diferente number of values. Please add NA to any empty cells.\n")
                print("The pipeline has not been adapted to insert this TAG to maintain the user control over the supplied data, but the user file can be automatically given the NA tag/value by uploading the original to the USER DATA CONTROL PAGE.")
                print("If your data contain empty cells this step can be performed by supplying the file location and hitting the replace empty button. Which will take your file add NA to all empty cells and give you a new output named NA-Original_File_Name.txt. This script will also clean any trailling lines left behind by csv files and tables.")

        if len(Animalwords) == len(Colorswords):
            #print("Valid")
            print("Equal lenght lists.\n")
            
            ## Stack both lists and create a 2N x M python pandas dataframe. Name: labels & columns. Use unique index.
            #dataframe = pd.DataFrame(np.column_stack([Animalwords, Colorswords]), columns=["Animal", "Color"])
            #print(dataframe)
            
            df = pd.DataFrame(list(zip(Animalwords, Colorswords)), columns =['Animal', 'Color']) 
            print(df)
# Out:
# ['cat', 'dog', 'cat', 'cat', 'dog', 'cat', 'cat']
# ['white', 'black', 'black', 'white', 'black', 'white', 'white']
#
# Number of Animals =  7
# Number of Colors =  7
# Equal lenght lists.
#
#   Animal  Color
# 0    cat  white
# 1    dog  black
# 2    cat  black
# 3    cat  white
# 4    dog  black
# 5    cat  white
# 6    cat  white

# %%
# 2D dataframe visualization.
df
# Out:
#   Animal  Color
# 0    cat  white
# 1    dog  black
# 2    cat  black
# 3    cat  white
# 4    dog  black
# 5    cat  white
# 6    cat  white

# %%
# Aggregating by animal and color for final Count
df.groupby('Animal')['Color'].value_counts()
# Out:
# Animal  Color
# cat     white    4
#         black    1
# dog     black    2
# Name: Color, dtype: int64

# %%
# To visualize different colors per animal.
df.groupby(['Animal', 'Color']).count()
# Out:
# Empty DataFrame
# Columns: []
# Index: [(cat, black), (cat, white), (dog, black)]

# %% [markdown]
# #### This code works for any number of animals, colors and list lenght.

# %% [markdown]
# <div class="alert alert-block alert-info"><h2 style="font-size:16px"style="padding:1px"><center>Q5. VISUALIZATION </center></h2>
# <p> We ordered a new wireless router to improve the Internet reliability. While everybody feels that the new router, we want to be data-driven. We ran 20 pings with the old and new routers. The data is shown below. Create a single figure with these data to convince some one if the new router is better than the old one. Note that the target audience is a layperson. Preferably complete this assignment in Python, and send the source code and the figure.
# </div>
# <div class="alert alert-block alert-warning"><h2 style="font-size:16px"style="padding:1px"><center>Q5. ANSWER </center></h2>
# <p>
# I would take the information that is truly informative given the question. The time of response for each router. Simply take the measured points and use them to plot two lines in a graph. Highlighting the time of response of the new modem compared to the old modem. This seems to be the type of answer this question is looking for.
#
# But simple the audience has no idea of any of that means I wouldn’t give that as the final answer for the audience. The main idea is to obviously and clearly show to the audience that the new router is faster and explain why this is important and even better why they should care about that response time and expend money on a new router.
#
# To convince someone that the new router is better and if they are completely acknowledge of the subject instead of any graph or visualization I would simply inform them of the average response time of one compared to the other.
#
# Get a figure with ROUTER-NEW AVERAGE  next to ROUTER-OLD AVERAGE. This figure would simply face a picture of the router with the average ping response time bellow which I would call ´how fast’ and on the side a picture of the older router and the response time bellow.
#
# Under this this figure display I would Have the following information written: YOUR NEW ROUTER WOULD BE _____ % FASTER than your older router. In simple terms this means your internet would ‘work’ that _________ %  amount faster.
#
# </div>

# %% [markdown]
# For each measurement ping and time for round-trip response are here taken as (x,y) one point will be graphed on the cartesian plane and a line drawn for the old_router.
# A second line will be plotted in the same manner for the new router.

# %%
df_old = pd.read_table('router_old.txt', delim_whitespace=True, names=("A", "B", "C", "D","E","F","G","H", "I", "Old", "L"))
df_old
# Out:
#      A      B     C              D         E   F    G   H     I      Old   L
# 0   64  bytes  from  172.217.10.4:  icmp_seq   0  ttl  51  time   11.912  ms
# 1   64  bytes  from  172.217.10.4:  icmp_seq   1  ttl  51  time   21.098  ms
# 2   64  bytes  from  172.217.10.4:  icmp_seq   2  ttl  51  time    7.113  ms
# 3   64  bytes  from  172.217.10.4:  icmp_seq   3  ttl  51  time    7.033  ms
# 4   64  bytes  from  172.217.10.4:  icmp_seq   4  ttl  51  time    5.456  ms
# 5   64  bytes  from  172.217.10.4:  icmp_seq   5  ttl  51  time   78.941  ms
# 6   64  bytes  from  172.217.10.4:  icmp_seq   6  ttl  51  time   10.592  ms
# 7   64  bytes  from  172.217.10.4:  icmp_seq   7  ttl  51  time    7.169  ms
# 8   64  bytes  from  172.217.10.4:  icmp_seq   8  ttl  51  time    4.850  ms
# 9   64  bytes  from  172.217.10.4:  icmp_seq   9  ttl  51  time   11.244  ms
# 10  64  bytes  from  172.217.10.4:  icmp_seq  10  ttl  51  time    4.920  ms
# ...

# %%
df_new = pd.read_table('router_new.txt', delim_whitespace=True, names =("An", "Bn", "Cn", "Dn","En","Fn","Gn","Hn", "In", "New", "Ln"))
df_new
# Out:
#     An     Bn    Cn              Dn        En  Fn   Gn  Hn    In    New  Ln
# 0   64  bytes  from  172.217.11.36:  icmp_seq   0  ttl  49  time  5.730  ms
# 1   64  bytes  from  172.217.11.36:  icmp_seq   1  ttl  49  time  5.673  ms
# 2   64  bytes  from  172.217.11.36:  icmp_seq   2  ttl  49  time  5.160  ms
# 3   64  bytes  from  172.217.11.36:  icmp_seq   3  ttl  49  time  5.651  ms
# 4   64  bytes  from  172.217.11.36:  icmp_seq   4  ttl  49  time  3.383  ms
# 5   64  bytes  from  172.217.11.36:  icmp_seq   5  ttl  49  time  5.135  ms
# 6   64  bytes  from  172.217.11.36:  icmp_seq   6  ttl  49  time  6.161  ms
# 7   64  bytes  from  172.217.11.36:  icmp_seq   7  ttl  49  time  4.919  ms
# 8   64  bytes  from  172.217.11.36:  icmp_seq   8  ttl  49  time  5.313  ms
# 9   64  bytes  from  172.217.11.36:  icmp_seq   9  ttl  49  time  4.059  ms
# 10  64  bytes  from  172.217.11.36:  icmp_seq  10  ttl  49  time  3.943  ms
# ...

# %%
#routers_df = df_old.append(df_new, sort=True)

routers_df = pd.concat([df_old, df_new], axis=1)
routers_df
# Out:
#      A      B     C              D         E   F    G   H     I      Old  ...  \
# 0   64  bytes  from  172.217.10.4:  icmp_seq   0  ttl  51  time   11.912  ...
# 1   64  bytes  from  172.217.10.4:  icmp_seq   1  ttl  51  time   21.098  ...
# 2   64  bytes  from  172.217.10.4:  icmp_seq   2  ttl  51  time    7.113  ...
# 3   64  bytes  from  172.217.10.4:  icmp_seq   3  ttl  51  time    7.033  ...
# 4   64  bytes  from  172.217.10.4:  icmp_seq   4  ttl  51  time    5.456  ...
# 5   64  bytes  from  172.217.10.4:  icmp_seq   5  ttl  51  time   78.941  ...
# 6   64  bytes  from  172.217.10.4:  icmp_seq   6  ttl  51  time   10.592  ...
# 7   64  bytes  from  172.217.10.4:  icmp_seq   7  ttl  51  time    7.169  ...
# 8   64  bytes  from  172.217.10.4:  icmp_seq   8  ttl  51  time    4.850  ...
# 9   64  bytes  from  172.217.10.4:  icmp_seq   9  ttl  51  time   11.244  ...
# 10  64  bytes  from  172.217.10.4:  icmp_seq  10  ttl  51  time    4.920  ...
# ...

# %%
df_fig = routers_df[["Old", "New"]]
df_fig
# Out:
#         Old    New
# 0    11.912  5.730
# 1    21.098  5.673
# 2     7.113  5.160
# 3     7.033  5.651
# 4     5.456  3.383
# 5    78.941  5.135
# 6    10.592  6.161
# 7     7.169  4.919
# 8     4.850  5.313
# 9    11.244  4.059
# 10    4.920  3.943
# 11  104.141  4.235
# 12    5.090  4.183
# 13    5.787  5.230
# 14    6.098  4.255
# 15    7.451  5.297
# 16    9.982  5.021
# 17    5.462  5.268
# 18   15.061  3.445
# 19    6.701  4.754

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')

# %%
df_fig.plot()
plt.legend(loc='best')

plt.xlabel('Ping(s)')
plt.ylabel('Runtime (secs)')
# Out:
# Text(0, 0.5, 'Runtime (secs)')

# %% [markdown]
# <div class="alert alert-block alert-info"><h2 style="font-size:14px"style="padding:1px"><center>Continued</center></h2>
# <p>
# The more user stories the better the 'final-release' product is. The more options to visualize all that is possible with a certain data the more informative, significant and trustworthy the science created from this product will be. And able to withstand critic, challenges and time due to its intrinsic design, that always tries to prove all its components wrong.
# Another important future aspect that needs the data to be handled with excessive care, review, standards, enrichment, principal components-per-sample definitions and so many others due to the possible future machine learning structures formed by this ocean of information that can then be used as features and layers for an AI to look for what is there. There might be a never seen correlation between two networks that have no equal nodes (disease, tissue, etc) but that when compared in its distances overlaps parts of one network onto of the others.<p>
# <p>
# A possible idea is to look near the overlaps location. Maybe there is a layer in the first network that defines color, where is that layer anchored and what is the direct corresponding anchor on the overlay? Does the overlay node has anything to do with color? <p>
# Everything evolved from a branch you can follow the evolution of a structure from the simplest life almost forms to complex animal life such as our own. This means the branches, its directions and the point from where they came from were once the same. A turtle lives a really long time, give all the information for that turtle tissues, protective carapaca and its protein, gene and its orthologs, expression, response to drugs and even to temperature all this as the beginning of a massive amount of accumulating layered network. Which each layer main node being structure as a dictionary with growing values assign to one key. All these keys are main values of other dictionaries.
# <p><p>
# It will be a ball-like universe on nodes, connections, linking path up/down and transversally. Now please AI use all the computation we can afford what does this turtle have that I don't. Give me all results and their 10-step downstream and upstream information. Isolated and create this as a new cosmos-like cluster of aging. Let's separate in modules and test.
# <p>
# *Ps.: For those who feel fatigue, D-Ribose is a good supplement, takes a different route and creates more energy for those lacking enough ATP/Energy production due to mitochondrial dysfunction, unbalanced diet and/or aging. <p>
# *Curiosity instigating blurb:<br>
# <p> ATP molecule is able to store and transport chemical energy within cells and is essential for synthesis of nucleus acids such as DNA and RNA. Ribose is a naturally occurring five-carbon sugar produced in the body through the PPP, a metabolic pathway parallel to glycolysis that generates nicotinamide adenine dinucleotide phosphate (NADPH), pentoses, and ribose 5-phosphate. The PPP is a slow process that requires an enzyme called glucose-6-phosphate dehydrogenase (G-6-PDH) that is often in short supply within the cells. This enzyme can have limited expression in the myocardial cells with cardiac disease leading to significant delay in the production of ribose.<p>
# In certain pathologic conditions such as heart failure, cellular energy deficiency exists in myocardial mitochondria. The reduction in ATP production is directly correlated with the decreased supply of D-ribose in the mitochondria. This may be related to the limited expression of the G-6-PDH enzyme in myocardium that can significantly interrupt the production of ribose. Several studies have shown that augmenting D-ribose following myocardial ischemia improves mitochondrial function by increasing myocardial ATP production.
# <p>
# Administering supplemental D-ribose circumvents the enzymatic step to assist with replenishing ATP levels in cells. In purine metabolism, D-glucose is transformed to both D-ribose-6-phosphate and to D-ribose-5-phosphate and then altered to 5-phospho-D-ribose 1-pyrophsophate (PRPP) for the synthesis of purine and pyrimidine. In other words, supplemental D-ribose bypasses the rate-controlling PPP (slower pathway) and provides an alternate source of PRPP for ATP production. <p>
# <p>
# D-ribose has been used both orally and intravenously in patients for many different pathologic conditions such as chronic fatigue syndrome, fibromyalgia, and myocardial dysfunction. It is often used to improve athletic performance and reduce symptoms of cramping, pain, and stiffness following exercise. Under different pathologic conditions, ATP, ADP, and adenosine monophosphate are degraded and not available for energy production. Supplemental D-ribose has been shown to enhance recovery of ATP levels and reduce cellular injury in humans and animals.
# <p>
# IN SUM: More energy, less felt effects of multiple diseases, less oxidative stress and a general feel better metabolism. Without a productive and efficiency energy metabolism, the body and its metabolism will start feeling and eventually will evolve to a system-wide adverse condition. <p>
# <p>
# Everything that can be improved in the metabolism should be since the accumulating metabolic sub-products are a main driver of aging, disease and cellular disfunctions.<p>
# *Another example when the permanent teeth take over, a signal from its base tells the entire body " It's time to get older, lets change the production to a bit older." It’s a maybe absurd idea but why not reduce that signal. Tooth I feel you might need to be stimulated into forgetting a permanent role, after all by 75 years old a new teeth-set would be welcomed.
# <p>
# *All in all, I would be willing to take a meal a day as a shake with 1000 different substances, calculated and mixed to help my body to function optimally. The 10 or so  pills I will happily take with added-extra-magnesium water, all in all being able to guarantee better brain function, feeding the brain easier with all co-factors, vitamins and even neurotransmitters precursors to supplement the non-optimum concentration of neurotransmitters as people age, especially after reaching 30 years-old. This is one of the reasons some people do not respond to antidepressants and other mental health medications that need to use/force the brain machinery to produce more neurotransmitters, if the machine is available but the input/the dirt to the neurotransmitters-bricks is not available and the necessary quantity the medication either does not work, needs a higher dose or stops working overtime. This is the main reason for medication-resistant depression.
# <p>
# The secret to longer healthy life is just a gigantic database away. Given enough computation, data curation, natural language processing and multiple in parallel instances running ML algorithms to connect information and then AI in parallel as highly-powered computation, informed-best-possible-decision-able genius scientists that never need to stop, this is not an out of reach goal, and a decade would be enough.
# <p>
# The road-map of the necessary work is ready. The work has to start and amazon needs to be kind and help fund the computation. The outline project is already written. Heck at this point I admit I'm getting carried-away but I happen to have read all of geo aging paper until 2017 and created aging collections, I have studied so much that it is only fair to say it’s possible I bet my life on it. Think of the implications for space-travel.
# <p>
# * Also given a target and knowing the necessary altered target-specific response coupled with the pathway up and down information any place can be hit by a design small molecule to hit the target, these changes are only to reduce, increase, block and delay the simplest target interactions, the signaling changes can be further studied in the future but specific target can be modulated in a simple pharmacology designed molecules with chosen degradation and/or re-uptake.
# <p>Every part of the metabolism can be targeted and hit-specifically the downstream effects and redundancy are the main issues which are to be given to the AI to figure out and give out a list of targets and their necessary modulation to achieve a final overall response.
# <p>
# <h5> Observation about this issue:</h5> Guess the above is my user story, get informative, high quality data, find meaning, enrich, inform, add more information and give it to ML and AI with directed research focus on aging and cognitive function. This is my research dream-goal and it will happen even if I have to find more ways to get funding, write the project (it’s a project with 15 sub-projects inside and identified government databases for background data (over 100 databases drug information, toxins and plant detailed 'medicinal' uses that can and are increasingly being characterized and the beneficial compounds then isolated and further developed before final-use-result (that is already known as part of the traditional medicine as effective being given higher efficiency, efficacy and less adverse effects due to the break-down of the traditional medicine keeping only the beneficial compounds, the rest is taken out of the developed drug/medication which increases its safety.<p>
#     <p>
# * My own anecdote I know personally and seen the effects over time of a mix of plants being a cure for vitiligo. As long as the concoction is taken it stops and reverts. I have seen the plant doctor and the patient with vitiligo and its reduction over time in two years it was gone and it will stay that way as long as he keeps drinking it, this was over 10 years ago. The reasoning behind the manipulated plant-mix medications is quite absurd and somewhat based in witch-doctor culture, tales and books. Yet the outcome of it, the final result is proven and has been tested on people for decades. I knew three plant-doctors in my childhood, two have passed away and the last one has kindly agreed to write his formulas down. This took me asking since childhood and thus the man has asked for some money so he can retire as long as it’s not forcibly taken, he and a couple of Indians according to him will pass it over to someone who is interested in keeping the knowledge alive. The ones I've seen over time, probed into the 'patients' complains and evolution and the vitiligo pictures I myself took is why I can say with confidence there are at least 5 new drugs with no other known treatment in the man’s 'office'. <p> Full disclose: I was taken there by my grandmother at about 5 year old and took an interest in the mixes and the vehicles the mixes are added to (usually wine, random cheap alcohol and even belladonna paste) which is why I know the details of his formulas, preparations and the source for his supply of Amazonian (mostly) plants. History tells an Indian taught him. <p>
#     <p>
# With all that is known in science and what can be made into scientific-knowledge looking for the pharmacology effects of each sequenced plant compounds, all in order and structured, with more computation, automation of pipelines, training datasets multiple times until the algorithms become highly trustworthy for highly specific stratifications(data-type-assay-tissue-age-otherCharacteristics without a limit of variables added to this stratified highly specific segments that will then be defined as gold standards and used as reference for comparisons against newer generated data/analysis that can be given different significant values per characteristics-segment-length. Lower number of characteristics will created more correlations but higher numbers will result in higher significance, by looking at the multiple segment length results, cross sections can be drawn and a limit for significance determined for each global category (or the main full network regions).<p>
#     <p>
# While a lot of data will be necessary with detailed information, globally the necessary data can be easily collected from hospitals, volunteers, collaborators and the researchers that which to add their own data, some researchers might be asked to make their data public and identified for further data enrichment which for people that can be tracked will be continuously aggregating information.<p>
#   <p>
# At face value the entire idea of aging research is dismissed as too difficult and too laborious. What I propose is the alternative view that accepts the amount of work as a necessity and having taken steps to start the required work is now personally seen as not only possible but also containing and easy to map route, it will a lot of work along the way but the route is ready and highlighted in the map.<p>
#     <p>
# Seeing what exist available already a 10 years project to map the route of aging, defining the rest-stops (targets) along the way with fine granularity of detail seem possible that in 5 years ML algorithms will be finishing their data structuring and node connections, given 3 years for the general cosmos-cluster network assembly then at the 8 year mark of the project official beginning an AI will be running as a main higher hierarchy decision that will control the limits and guide pre-sets enforcing conditions defined as vital such as those conditions and limits to which human survival is subjected to and the window(ranges) acceptable for each category and then the limit per category_item thus constraining the search to those that are viable for human/mammals life without serious adverse effects (such as liver damage, accumulating toxic substances, non-acceptable targets (brain, brain-barrier, placenta-barrier) these need to be taken to a round table of human specialists in the target location medicine, researchers, biologists, pharmacologists and biochemistry which will each give a report as pros and cons according to their own science and knowledge, guaranteeing a multi-sided view that will then be used to create a detailed report that should be submitted to and ethics committee along with the round-table target reach-hit-modulating strategy for ethics review, once approved the authorization to continue target investigation given the agreed as per round-table and ethics committee approved limits will be given to the main AI, documented and registered with proper ethical and legal protocols. <p>
#     <p>
#     *Once an decision is approved by the round-table (containing name, specialty, specific-report-ID created by the individual that responds as responsible for that specific report-ID, each individual responsibility is limited to the information documented on the written report, this person can request a second, third up to five opinions of specialist who shall answer the same questions and provide each one report the majority on each field is them defined as the final report.) The specialists on each area should be chosen previously in sufficient number, with no upper limit just a minimal limit defined as over 12 specialists per area. These steps; creating of the round-table and of the ethics committee are required to fulfill the applicable laws, guidelines and The WHO ethical requirements and good research practices. <p>
# <p>
# At the 10 year mark the target list should contain multiple targets and their metabolic result. As the target list grows and the result achieve moves closer to the desired outcome new treatments possibilities for multiple diseases will be 'found' as possible from those a secondary research focus area will be explored for disease-specific treatment possibilities.
# <p> <p>
# At the 15 year mark the supplement shake and pills should be going to phase III trials. Phase I and II trials are accelerated by the limits set as human survival window that is enforced at the highest hierarchical level. Necessary Phase I and II test are part of the predictions and also help guide the AI choices (teratogenic compounds for instance are banned from use, maximum dose per substance type-effect-class are also predicted (saturation is calculated using the substance chemical characteristics) the pharmacopeia which contains descriptions and reference values/limits for all tests a drug needs to be subjected too to be safe, bioavailability (AUC), determine how long the good for consumption period, packing type depends on medication compounds sensitivity mostly to light and is used to define package color and material. The dilution time of a pill and its resistance to applied force until break, spectrophotometry and gas chromatography values are also predicted based on chemical characteristics all these are part of the background knowledge and basing information that will be available to inform and guide decisions.
# <p> <p>
# </div>
